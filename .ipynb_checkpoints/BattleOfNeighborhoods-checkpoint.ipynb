# %% [markdown]
# # Battle Of Neighborhoods
# ## Capstone Project
# ### IBM Data Science Professional Certificate
# https://www.coursera.org/learn/applied-data-science-capstone

# %% [markdown]
# #### Business problem description
#
# Which is the most recommended location for living in London assuming you want to study at Middlesex University? The accommodation needs to be close to the university, but not too far from the city centre. Supermarkets and cafes in the neighborhood will also be taken into consideration. However, being a student the rent is a key factor to bear in mind. A one bedroom house or flat is preferred.
#
# London is a large city with plenty of opportunities. There are many interesting spots in this city, touristic attractions, monuments and even business areas. All these factors are important for looking for accommodation. Rental prices in London are high, the area must be chosen in a way that minimises it while still enjoying the proximity to the key locations mentioned before.
#
# The target audience is university students who are looking for accommodation in London, and don't want to give up on all the beauties of London.

# %% [markdown]
# #### Data
#
# The different boroughs of London will be checked, searching for venues of interest and average rental prices.
#
# Data sources:
# - Foursquare
# - https://data.london.gov.uk/dataset/average-private-rents-borough
# - https://data.london.gov.uk/dataset/postcode-directory-for-london
# - https://www.freemaptools.com/download/outcode-postcodes/postcode-outcodes.csv
# - https://www.doogal.co.uk/PostcodeDistrictsCSV.ashx
#
# The accomodation must be located close to Middlesex University. Foursquare data will be used to search for venues around this location. The postcode directory of the city will be used to group the venues information and average rent per area by borough.

# %% [markdown]
# #### Data import and preprocessing

# %%
import pandas as pd
import numpy as np
import requests # library to handle requests
from pandas.io.json import json_normalize

# %%
#!pip install geopy
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

address = "Middlesex University London"
geolocator = Nominatim(user_agent="London_Accommodation")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geographical coordinates of {} are {}, {}.'.format(address, latitude, longitude))
# Out:
# The geographical coordinates of Middlesex University London are 51.590297050000004, -0.2296322094540291.

# %%
# Import the UK postcodes from CSV file
url = 'https://www.doogal.co.uk/PostcodeDistrictsCSV.ashx'
dfs = pd.read_csv(url)
dfs.head(3)
# Out:
#   Postcode  Latitude  Longitude   Easting  Northing Grid Reference Town/Area  \
# 0      AB1   57.1269   -2.13644  391839.0  804005.0       NJ918040  Aberdeen
# 1      AB2   57.1713   -2.14152  391541.0  808948.0       NJ915089  Aberdeen
# 2      AB3   57.0876   -2.59624  363963.0  799780.0       NO639997  Aberdeen
#
#      Region  Postcodes  Active postcodes  Population  Households  \
# 0  Aberdeen     2655.0               0.0         NaN         NaN
# 1  Aberdeen     3070.0               0.0         NaN         NaN
# 2  Aberdeen     2168.0               0.0         NaN         NaN
#
#                                     Nearby districts
# 0  AB10, AB9, AB15, AB25, AB2, AB12, AB16, AB11, ...
# 1  AB16, AB22, AB24, AB25, AB1, AB9, AB15, AB10, ...
# 2  AB31, AB34, AB52, AB33, AB14, AB32, AB30, AB13...

# %% [markdown]
# Select only those postcodes in the area of interest in order to reduce the amount of data. These postcodes are those starting wih NW, E, N and W.

# %%
dfpc = dfs[dfs['Postcode'].str.match('^NW\d|^E\d|^N\d|^W\d')]
dfpc = dfpc[~dfpc['Town/Area'].str.contains('Non-geographic')]

# %% [markdown]
# Drop the non-useful columns.

# %%
dfpc.drop(['Easting', 'Northing', 'Grid Reference', 'Active postcodes', 'Postcodes', 'Population', 'Households', 'Nearby districts'], axis=1, inplace=True)

# %%
# Show resulting dataframe
dfpc
# Out:
#      Postcode  Latitude  Longitude  \
# 805        E1   51.5163  -0.060428
# 806       E1W   51.5118  -0.059323
# 807        E2   51.5301  -0.062251
# 808        E3   51.5282  -0.025800
# 809        E4   51.6238  -0.003245
# ...       ...       ...        ...
# 2946      W10   51.5202  -0.221196
# 2947      W11   51.5128  -0.216585
# 2948      W12   51.5094  -0.238236
# 2949      W13   51.5131  -0.321423
# 2950      W14   51.4954  -0.211163
#
#                                               Town/Area  \
# 805   Aldgate, Bishopsgate, Whitechapel, Shoreditch,...
# 806                                             Wapping
# 807   Bethnal Green, Haggerston, Shoreditch, Cambrid...
# 808   Bow, Bromley-by-Bow, Old Ford, Mile End, Three...
# 809                Chingford, Sewardstone, Highams Park
# ...                                                 ...
# 2946                      North Kensington, Queens Park
# 2947                         Notting Hill, Holland Park
# 2948                         Shepherds Bush, White City
# 2949                           West Ealing, Northfields
# 2950  West Kensington, Kensington Olympia, Holland Park
#
#                       Region
# 805            Tower Hamlets
# 806            Tower Hamlets
# 807            Tower Hamlets
# 808            Tower Hamlets
# 809           Waltham Forest
# ...                      ...
# 2946  Kensington and Chelsea
# 2947  Kensington and Chelsea
# 2948  Hammersmith and Fulham
# 2949                  Ealing
# 2950  Kensington and Chelsea
#
# [86 rows x 5 columns]

# %% [markdown]
# The next step is importing the data about rental prices by area and match it with the dataframe containing the postcodes of interest.

# %%
# Import the UK rental prices from CSV file
url = 'https://data.london.gov.uk/download/average-private-rents-borough/73b9fb07-b5bb-4a53-88b7-c17269879a08/voa-average-rent-borough.xls'
dfr = pd.read_excel(url, index_col=None, header=2, sheet_name='Raw data')
dfr.head(3)
# Out:
#    Year Quarter       Code                  Area Category Count of rents  \
# 0  2011      Q2  E09000001        City of London     Room              -
# 1  2011      Q2  E09000002  Barking and Dagenham     Room             92
# 2  2011      Q2  E09000003                Barnet     Room            945
#
#   Average Lower quartile Median Upper quartile
# 0       -              -      -              -
# 1     336            282    347            390
# 2     450            399    433            500

# %% [markdown]
# Keep only the rents for the last year.

# %%
dfr = dfr[dfr['Year'] == dfr['Year'].max()]
dfr.head()
# Out:
#       Year Quarter       Code                  Area Category Count of rents  \
# 5852  2019      Q1  E09000001        City of London     Room              0
# 5853  2019      Q1  E09000002  Barking and Dagenham     Room             10
# 5854  2019      Q1  E09000003                Barnet     Room             50
# 5855  2019      Q1  E09000004                Bexley     Room             40
# 5856  2019      Q1  E09000005                 Brent     Room             90
#
#      Average Lower quartile Median Upper quartile
# 5852       .              .      .              .
# 5853     650            600    650            700
# 5854     602            550    588            650
# 5855     577            550    585            672
# 5856     638            500    602            700

# %% [markdown]
# Filter by one bedroom houses.

# %%
dfr = dfr[dfr['Category'] == 'One Bedroom']

# %% [markdown]
# Clean table

# %%
dfr.drop(['Year', 'Code', 'Category', 'Count of rents', 'Lower quartile', 'Median', 'Upper quartile'], axis=1, inplace=True)

# %% [markdown]
# Check data types.

# %%
dfr.dtypes
# Out:
# Quarter    object
# Area       object
# Average    object
# dtype: object

# %% [markdown]
# Convert Average column to numbers.

# %%
dfr = dfr.astype({'Average': 'int64'})
dfr.dtypes
# Out:
# Quarter    object
# Area       object
# Average     int64
# dtype: object

# %% [markdown]
# Group by area in order to average the rents on the four quarters.

# %%
dfr = dfr.groupby('Area').mean().reset_index()

# %% [markdown]
# Rename average rent column as Rent

# %%
dfr = dfr.rename(columns={'Average': 'Rent'}, errors="raise")
dfr['Area'] = dfr['Area'].str.title()

# %%
dfr
# Out:
#                         Area  Rent
# 0       Barking And Dagenham   965
# 1                     Barnet  1147
# 2                     Bexley   821
# 3                      Brent  1241
# 4                    Bromley   972
# 5                     Camden  1659
# 6             City Of London  2083
# 7                    Croydon   931
# 8                       East   666
# 9              East Midlands   481
# 10                    Ealing  1216
# 11                   Enfield  1083
# 12                 Greenwich  1155
# 13                   Hackney  1523
# 14    Hammersmith And Fulham  1454
# 15                  Haringey  1259
# 16                    Harrow  1093
# 17                  Havering   889
# 18                Hillingdon  1018
# 19                  Hounslow  1153
# 20              Inner London  1544
# 21                 Islington  1558
# 22    Kensington And Chelsea  2062
# 23      Kingston Upon Thames  1123
# 24                    London  1350
# 25                   Lambeth  1370
# 26                  Lewisham  1130
# 27                    Merton  1220
# 28                North East   426
# 29                North West   492
# 30                    Newham  1202
# 31              Outer London  1081
# 32                 Redbridge  1006
# 33      Richmond Upon Thames  1242
# 34                South East   718
# 35                South West   584
# 36                 Southwark  1419
# 37                    Sutton   920
# 38             Tower Hamlets  1494
# 39             West Midlands   514
# 40            Waltham Forest  1089
# 41                Wandsworth  1388
# 42               Westminster  2016
# 43  Yorkshire And The Humber   470

# %% [markdown]
# Go back to dataframe containing postcodes and coordinates.

# %%
dfpc['Region'] = dfpc['Region'].str.title()
dfpc['Region'].unique()
# Out:
# array(['Tower Hamlets', 'Waltham Forest', 'Hackney', 'Newham',
#        'Redbridge', 'Camden', 'Barnet', 'Haringey', 'Islington',
#        'Enfield', 'Brent', 'Westminster', 'London', 'Ealing', 'Hounslow',
#        'Hammersmith And Fulham', 'Kensington And Chelsea'], dtype=object)

# %% [markdown]
# Left join of postal codes dataframe with rents dataframe

# %%
df_rents = dfpc.merge(dfr, how='left', left_on='Region', right_on='Area')
df_rents
# Out:
#    Postcode  Latitude  Longitude  \
# 0        E1   51.5163  -0.060428
# 1       E1W   51.5118  -0.059323
# 2        E2   51.5301  -0.062251
# 3        E3   51.5282  -0.025800
# 4        E4   51.6238  -0.003245
# ..      ...       ...        ...
# 81      W10   51.5202  -0.221196
# 82      W11   51.5128  -0.216585
# 83      W12   51.5094  -0.238236
# 84      W13   51.5131  -0.321423
# 85      W14   51.4954  -0.211163
#
#                                             Town/Area                  Region  \
# 0   Aldgate, Bishopsgate, Whitechapel, Shoreditch,...           Tower Hamlets
# 1                                             Wapping           Tower Hamlets
# 2   Bethnal Green, Haggerston, Shoreditch, Cambrid...           Tower Hamlets
# 3   Bow, Bromley-by-Bow, Old Ford, Mile End, Three...           Tower Hamlets
# 4                Chingford, Sewardstone, Highams Park          Waltham Forest
# ..                                                ...                     ...
# 81                      North Kensington, Queens Park  Kensington And Chelsea
# 82                         Notting Hill, Holland Park  Kensington And Chelsea
# 83                         Shepherds Bush, White City  Hammersmith And Fulham
# 84                           West Ealing, Northfields                  Ealing
# 85  West Kensington, Kensington Olympia, Holland Park  Kensington And Chelsea
#
#                       Area  Rent
# 0            Tower Hamlets  1494
# 1            Tower Hamlets  1494
# 2            Tower Hamlets  1494
# 3            Tower Hamlets  1494
# 4           Waltham Forest  1089
# ..                     ...   ...
# 81  Kensington And Chelsea  2062
# 82  Kensington And Chelsea  2062
# 83  Hammersmith And Fulham  1454
# 84                  Ealing  1216
# 85  Kensington And Chelsea  2062
#
# [86 rows x 7 columns]

# %%
# Verify that the merge has been done correctly by checking the number of NaN values
df_rents['Rent'].isna().value_counts()
# Out:
# False    86
# Name: Rent, dtype: int64

# %%
df_rents.drop(['Area'], axis=1, inplace=True)

# %%
df_rents.head()
# Out:
#   Postcode  Latitude  Longitude  \
# 0       E1   51.5163  -0.060428
# 1      E1W   51.5118  -0.059323
# 2       E2   51.5301  -0.062251
# 3       E3   51.5282  -0.025800
# 4       E4   51.6238  -0.003245
#
#                                            Town/Area          Region  Rent
# 0  Aldgate, Bishopsgate, Whitechapel, Shoreditch,...   Tower Hamlets  1494
# 1                                            Wapping   Tower Hamlets  1494
# 2  Bethnal Green, Haggerston, Shoreditch, Cambrid...   Tower Hamlets  1494
# 3  Bow, Bromley-by-Bow, Old Ford, Mile End, Three...   Tower Hamlets  1494
# 4               Chingford, Sewardstone, Highams Park  Waltham Forest  1089

# %%
latitude
# Out:
# 51.590297050000004

# %%
import folium # map rendering library

# create map of London using latitude and longitude values
map_london = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(df_rents['Latitude'], df_rents['Longitude'], df_rents['Postcode'], df_rents['Region']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_london)  

# add Middlesex University as a red circle mark
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Middlesex University',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(map_london)
    
map_london
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Calculate distance between university and each area

# %%
df_rents['lat'] = np.radians(df_rents['Latitude'])
df_rents['lon'] = np.radians(df_rents['Longitude'])

# %%
from sklearn.neighbors import DistanceMetric
dist = DistanceMetric.get_metric('euclidean')
latlon = df_rents[['lat','lon']].to_numpy()

# %%
# Append coordinates of Middlesex University to lat and lon columns
df_dist = df_rents[['lat','lon']].append(pd.DataFrame([[np.radians(latitude), np.radians(longitude)]], columns=list(['lat', 'lon'])))
df_dist
# Out:
#          lat       lon
# 0   0.899129 -0.001055
# 1   0.899051 -0.001035
# 2   0.899370 -0.001086
# 3   0.899337 -0.000450
# 4   0.901005 -0.000057
# ..       ...       ...
# 82  0.899068 -0.003780
# 83  0.899009 -0.004158
# 84  0.899073 -0.005610
# 85  0.898764 -0.003685
# 0   0.900421 -0.004008
#
# [87 rows x 2 columns]

# %% [markdown]
# Calculate the distance between all locations

# %%
dist_array = dist.pairwise(df_dist.to_numpy())*6373
dist_matrix = pd.DataFrame(dist_array,  columns=df_dist.index, index=df_dist.index)

# %%
df_rents['Distance University'] = dist_matrix.iloc[:-1,-1]
df_rents.head()
# Out:
#   Postcode  Latitude  Longitude  \
# 0       E1   51.5163  -0.060428
# 1      E1W   51.5118  -0.059323
# 2       E2   51.5301  -0.062251
# 3       E3   51.5282  -0.025800
# 4       E4   51.6238  -0.003245
#
#                                            Town/Area          Region  Rent  \
# 0  Aldgate, Bishopsgate, Whitechapel, Shoreditch,...   Tower Hamlets  1494
# 1                                            Wapping   Tower Hamlets  1494
# 2  Bethnal Green, Haggerston, Shoreditch, Cambrid...   Tower Hamlets  1494
# 3  Bow, Bromley-by-Bow, Old Ford, Mile End, Three...   Tower Hamlets  1494
# 4               Chingford, Sewardstone, Highams Park  Waltham Forest  1089
#
#    Distance University       lat       lon
# 0            20.541551  0.899129 -0.001055
# 1            20.858766  0.899051 -0.001035
# 2            19.785227  0.899370 -0.001086
# 3            23.701012  0.899337 -0.000450
# 4            25.455246  0.901005 -0.000057

# %% [markdown]
# Calculate the distance to the city centre, for example to Piccadilly Circus.

# %%
address_pc = "Piccadilly Circus, London"
geolocator = Nominatim(user_agent="London_Accommodation")
location = geolocator.geocode(address_pc)
latitude_pc = location.latitude
longitude_pc = location.longitude
print('The geographical coordinates of {} are {}, {}.'.format(address_pc, latitude_pc, longitude_pc))
# Out:
# The geographical coordinates of Piccadilly Circus, London are 51.5097922, -0.13442883634595293.

# %%
# Append coordinates of Piccadilly Circus to lat and lon columns
df_dist = df_rents[['lat','lon']].append(pd.DataFrame([[np.radians(latitude_pc), np.radians(longitude_pc)]], columns=list(['lat', 'lon'])))
df_dist
# Out:
#          lat       lon
# 0   0.899129 -0.001055
# 1   0.899051 -0.001035
# 2   0.899370 -0.001086
# 3   0.899337 -0.000450
# 4   0.901005 -0.000057
# ..       ...       ...
# 82  0.899068 -0.003780
# 83  0.899009 -0.004158
# 84  0.899073 -0.005610
# 85  0.898764 -0.003685
# 0   0.899015 -0.002346
#
# [87 rows x 2 columns]

# %%
dist_array = dist.pairwise(df_dist.to_numpy())*6373
dist_matrix = pd.DataFrame(dist_array,  columns=df_dist.index, index=df_dist.index)

# %%
df_rents['Distance Centre'] = dist_matrix.iloc[:-1,-1]
df_rents.drop(['lat', 'lon'], axis=1, inplace=True)
df_rents.head()
# Out:
#   Postcode  Latitude  Longitude  \
# 0       E1   51.5163  -0.060428
# 1      E1W   51.5118  -0.059323
# 2       E2   51.5301  -0.062251
# 3       E3   51.5282  -0.025800
# 4       E4   51.6238  -0.003245
#
#                                            Town/Area          Region  Rent  \
# 0  Aldgate, Bishopsgate, Whitechapel, Shoreditch,...   Tower Hamlets  1494
# 1                                            Wapping   Tower Hamlets  1494
# 2  Bethnal Green, Haggerston, Shoreditch, Cambrid...   Tower Hamlets  1494
# 3  Bow, Bromley-by-Bow, Old Ford, Mile End, Three...   Tower Hamlets  1494
# 4               Chingford, Sewardstone, Highams Park  Waltham Forest  1089
#
#    Distance University  Distance Centre
# 0            20.541551         8.262813
# 1            20.858766         8.356972
# 2            19.785227         8.340069
# 3            23.701012        12.255042
# 4            25.455246        19.331905

# %%
df_rents['Total Distance'] = df_rents['Distance University'] + df_rents['Distance Centre']
df_rents
# Out:
#    Postcode  Latitude  Longitude  \
# 0        E1   51.5163  -0.060428
# 1       E1W   51.5118  -0.059323
# 2        E2   51.5301  -0.062251
# 3        E3   51.5282  -0.025800
# 4        E4   51.6238  -0.003245
# ..      ...       ...        ...
# 81      W10   51.5202  -0.221196
# 82      W11   51.5128  -0.216585
# 83      W12   51.5094  -0.238236
# 84      W13   51.5131  -0.321423
# 85      W14   51.4954  -0.211163
#
#                                             Town/Area                  Region  \
# 0   Aldgate, Bishopsgate, Whitechapel, Shoreditch,...           Tower Hamlets
# 1                                             Wapping           Tower Hamlets
# 2   Bethnal Green, Haggerston, Shoreditch, Cambrid...           Tower Hamlets
# 3   Bow, Bromley-by-Bow, Old Ford, Mile End, Three...           Tower Hamlets
# 4                Chingford, Sewardstone, Highams Park          Waltham Forest
# ..                                                ...                     ...
# 81                      North Kensington, Queens Park  Kensington And Chelsea
# 82                         Notting Hill, Holland Park  Kensington And Chelsea
# 83                         Shepherds Bush, White City  Hammersmith And Fulham
# 84                           West Ealing, Northfields                  Ealing
# 85  West Kensington, Kensington Olympia, Holland Park  Kensington And Chelsea
#
#     Rent  Distance University  Distance Centre  Total Distance
# 0   1494            20.541551         8.262813       28.804364
# 1   1494            20.858766         8.356972       29.215738
# 2   1494            19.785227         8.340069       28.125296
# 3   1494            23.701012        12.255042       35.956053
# 4   1089            25.455246        19.331905       44.787152
# ..   ...                  ...              ...             ...
# 81  2062             7.853146         9.720280       17.573426
# 82  2062             8.741294         9.144339       17.885632
# 83  1454             9.048913        11.546536       20.595449
# 84  1216            13.340596        20.802584       34.143179
# 85  2062            10.753435         8.683957       19.437392
#
# [86 rows x 9 columns]

# %% [markdown]
# #### Extract information of venues

# %%
CLIENT_ID = 'FUBQR1NVAJTE4PBVEDP1WP2GYBBCGP5YYPF2F13N1WK5FETG' # Foursquare ID
CLIENT_SECRET = 'C2O004RGNK1CWTC1CYHS3PZUJDSDACW5C3NPFE0YJPGQLVFJ' # Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentials:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentials:
# CLIENT_ID: FUBQR1NVAJTE4PBVEDP1WP2GYBBCGP5YYPF2F13N1WK5FETG
# CLIENT_SECRET:C2O004RGNK1CWTC1CYHS3PZUJDSDACW5C3NPFE0YJPGQLVFJ

# %%
search_query = '52f2ab2ebcbc57f1066b8b46' # Supermarkets
radius = 15000
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&categoryId={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=FUBQR1NVAJTE4PBVEDP1WP2GYBBCGP5YYPF2F13N1WK5FETG&client_secret=C2O004RGNK1CWTC1CYHS3PZUJDSDACW5C3NPFE0YJPGQLVFJ&ll=51.590297050000004,-0.2296322094540291&v=20180604&categoryId=52f2ab2ebcbc57f1066b8b46&radius=15000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ee8ca01ad40e14f6418cc3a'},
#  'response': {'venues': [{'id': '5b1ebc890d0877001c28dcd0',
#     'name': "Sainsbury's",
#     'location': {'address': 'Smithfield Square, High Street Hornsey',
#      'lat': 51.587938546653874,
#      'lng': -0.11693457982305144,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.587938546653874,
#        'lng': -0.11693457982305144}],
#      'distance': 7798,
#      'postalCode': 'N8 7SA',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Smithfield Square, High Street Hornsey',
#       'London',
#       'Greater London',
#       'N8 7SA',
#       'United Kingdom']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314867',
#     'hasPerk': False},
#    {'id': '4b9395f9f964a520404934e3',
#     'name': "Sainsbury's",
#     'location': {'address': '27 Townmead Road, Fulham',
#      'lat': 51.467446896425635,
#      'lng': -0.18709600909845747,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.467446896425635,
#        'lng': -0.18709600909845747}],
#      'distance': 13989,
#      'postalCode': 'SW6 2SY',
#      'cc': 'GB',
#      'neighborhood': 'Sands End, London, Greater London',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['27 Townmead Road, Fulham',
#       'London',
#       'Greater London',
#       'SW6 2SY',
#       'United Kingdom']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314867',
#     'hasPerk': False},
#    {'id': '4b40b944f964a52059ba25e3',
#     'name': 'Waitrose & Partners',
#     'location': {'address': '366 Holloway Road',
#      'lat': 51.5561281,
#      'lng': -0.1161237,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.5561281,
#        'lng': -0.1161237}],
#      'distance': 8725,
#      'postalCode': 'N7 6PA',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['366 Holloway Road',
#       'London',
#       'Greater London',
#       'N7 6PA',
#       'United Kingdom']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314867',
#     'hasPerk': False},
#    {'id': '4b423c50f964a520b7cf25e3',
#     'name': "Sainsbury's",
#     'location': {'address': '147-151 Balham High Rd',
#      'lat': 51.443757695962844,
#      'lng': -0.15087394325478787,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.443757695962844,
#        'lng': -0.15087394325478787}],
#      'distance': 17200,
#      'postalCode': 'SW12 9AU',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['147-151 Balham High Rd',
#       'London',
#       'Greater London',
#       'SW12 9AU',
#       'United Kingdom']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314867',
#     'hasPerk': False},
#    {'id': '4b504755f964a520a61f27e3',
#     'name': 'Waitrose & Partners',
#     'location': {'address': '273 Ballards Lane',
#      'lat': 51.6113840885588,
#      'lng': -0.1800974874822714,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.6113840885588,
#        'lng': -0.1800974874822714}],
#      'distance': 4152,
#      'postalCode': 'N12 8NR',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['273 Ballards Lane',
#       'London',
#       'Greater London',
#       'N12 8NR',
#       'United Kingdom']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314867',
#     'hasPerk': False},
#    {'id': '4bae6f13f964a520ebb13be3',
#     'name': 'Morrisons',
#     'location': {'address': '10 Hertslet Rd',
#      'lat': 51.55759405229233,
#      'lng': -0.11673014294411835,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.55759405229233,
#        'lng': -0.11673014294411835}],
#      'distance': 8617,
#      'postalCode': 'N7 6PL',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['10 Hertslet Rd',
#       'Holloway',
#       'Greater London',
#       'N7 6PL',
#       'United Kingdom']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314867',
#     'hasPerk': False},
#    {'id': '4bb4c0e0a7059521599e1bce',
#     'name': 'Tesco',
#     'location': {'address': '1 Ash Hill Dr',
#      'lat': 51.596881,
#      'lng': -0.3959728,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.596881,
#        'lng': -0.3959728}],
#      'distance': 11526,
#      'postalCode': 'HA5 2AG',
#      'cc': 'GB',
#      'city': 'Pinner',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['1 Ash Hill Dr',
#       'Pinner',
#       'Greater London',
#       'HA5 2AG',
#       'United Kingdom']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314867',
#     'hasPerk': False},
#    {'id': '4adb2727f964a520902421e3',
#     'name': "Sainsbury's",
#     'location': {'address': '62 Wandsworth Rd',
#      'lat': 51.4803821,
#      'lng': -0.1283605,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.4803821,
#        'lng': -0.1283605}],
#      'distance': 14102,
#      'postalCode': 'SW8 2LF',
#      'cc': 'GB',
#      'city': 'Battersea',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['62 Wandsworth Rd',
#       'Battersea',
#       'Greater London',
#       'SW8 2LF',
#       'United Kingdom']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314867',
#     'hasPerk': False},
#    {'id': '4d51574a3062a1cd27e065a3',
#     'name': 'Morrisons',
#     'location': {'address': 'Stirling Way',
#      'crossStreet': 'Stirling Corner',
#      'lat': 51.6442289130016,
#      'lng': -0.25599082584512084,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.6442289130016,
#        'lng': -0.25599082584512084}],
#      'distance': 6273,
#      'postalCode': 'WD6 2RN',
#      'cc': 'GB',
#      'city': 'Borehamwood',
#      'state': 'Hertfordshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Stirling Way (Stirling Corner)',
#       'Borehamwood',
#       'Hertfordshire',
#       'WD6 2RN',
#       'United Kingdom']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314867',
#     'hasPerk': False},
#    {'id': '4ac518eef964a520efac20e3',
#     'name': 'Asda',
#     'location': {'address': '204 Lavender Hill, Battersea',
#      'lat': 51.465371,
#      'lng': -0.164962,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.465371,
#        'lng': -0.164962}],
#      'distance': 14610,
#      'postalCode': 'SW11 1JG',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['204 Lavender Hill, Battersea',
#       'London',
#       'Greater London',
#       'SW11 1JG',
#       'United Kingdom']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314867',
#     'hasPerk': False},
#    {'id': '4b8a4955f964a5200a6732e3',
#     'name': 'Tesco Extra',
#     'location': {'address': 'Shenley Road',
#      'lat': 51.6557614,
#      'lng': -0.2684901,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.6557614,
#        'lng': -0.2684901}],
#      'distance': 7766,
#      'postalCode': 'WD6 1JG',
#      'cc': 'GB',
#      'city': 'Borehamwood',
#      'state': 'Hertfordshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Shenley Road',
#       'Borehamwood',
#       'Hertfordshire',
#       'WD6 1JG',
#       'United Kingdom']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314867',
#     'hasPerk': False},
#    {'id': '4bf6cec6b182c9b67d87745a',
#     'name': 'Tesco',
#     'location': {'address': '180 Shepherds Bush Rd',
#      'lat': 51.49768639017431,
#      'lng': -0.22397518157958984,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.49768639017431,
#        'lng': -0.22397518157958984}],
#      'distance': 10316,
#      'postalCode': 'W6 7NL',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['180 Shepherds Bush Rd',
#       'London',
#       'Greater London',
#       'W6 7NL',
#       'United Kingdom']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314867',
#     'hasPerk': False},
#    {'id': '4b6b0cdcf964a52056ef2be3',
#     'name': 'Tesco Extra',
#     'location': {'address': '239-241 Lower High St',
#      'lat': 51.651691289419425,
#      'lng': -0.38761801086366177,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.651691289419425,
#        'lng': -0.38761801086366177}],
#      'distance': 12881,
#      'postalCode': 'WD17 2BD',
#      'cc': 'GB',
#      'city': 'Watford',
#      'state': 'Hertfordshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['239-241 Lower High St',
#       'Watford',
#       'Hertfordshire',
#       'WD17 2BD',
#       'United Kingdom']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314867',
#     'hasPerk': False},
#    {'id': '4af5a598f964a520c7fa21e3',
#     'name': "Sainsbury's",
#     'location': {'address': '31 Essex Pl',
#      'lat': 51.493518354927815,
#      'lng': -0.2652964245195477,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.493518354927815,
#        'lng': -0.2652964245195477}],
#      'distance': 11052,
#      'postalCode': 'W4 5UT',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['31 Essex Pl',
#       'London',
#       'Greater London',
#       'W4 5UT',
#       'United Kingdom']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314867',
#     'hasPerk': False},
#    {'id': '4b2f8a52f964a5202eec24e3',
#     'name': "Sainsbury's",
#     'location': {'address': 'Kingsland Shopping Centre',
#      'lat': 51.54773660349962,
#      'lng': -0.07422655231529296,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.54773660349962,
#        'lng': -0.07422655231529296}],
#      'distance': 11750,
#      'postalCode': 'E8 2LX',
#      'cc': 'GB',
#      'city': 'Dalston',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Kingsland Shopping Centre',
#       'Dalston',
#       'Greater London',
#       'E8 2LX',
#       'United Kingdom']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314867',
#     'hasPerk': False},
#    {'id': '4afdc918f964a520db2a22e3',
#     'name': "Sainsbury's",
#     'location': {'address': '2 Canal Way, Ladbroke Grove',
#      'crossStreet': 'Ladbrook Grove',
#      'lat': 51.526176882320165,
#      'lng': -0.2177618921320068,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.526176882320165,
#        'lng': -0.2177618921320068}],
#      'distance': 7184,
#      'postalCode': 'W10 5AA',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['2 Canal Way, Ladbroke Grove (Ladbrook Grove)',
#       'London',
#       'Greater London',
#       'W10 5AA',
#       'United Kingdom']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314867',
#     'hasPerk': False},
#    {'id': '4b9cef20f964a520578336e3',
#     'name': "Sainsbury's",
#     'location': {'address': '1 Cambridge Heath Rd',
#      'lat': 51.521153673148426,
#      'lng': -0.05863679125362786,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.521153673148426,
#        'lng': -0.05863679125362786}],
#      'distance': 14117,
#      'postalCode': 'E1 5SD',
#      'cc': 'GB',
#      'city': 'Whitechapel',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['1 Cambridge Heath Rd',
#       'Whitechapel',
#       'Greater London',
#       'E1 5SD',
#       'United Kingdom']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314867',
#     'hasPerk': False},
#    {'id': '4b20fb61f964a520c73524e3',
#     'name': 'Waitrose & Partners',
#     'location': {'address': 'Whitecross Street',
#      'crossStreet': 'at Whitecross St',
#      'lat': 51.52220708,
#      'lng': -0.09199505,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.52220708,
#        'lng': -0.09199505}],
#      'distance': 12173,
#      'postalCode': 'EC1Y 8NX',
#      'cc': 'GB',
#      'city': 'Barbican',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Whitecross Street (at Whitecross St)',
#       'Barbican',
#       'Greater London',
#       'EC1Y 8NX',
#       'United Kingdom']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '564499583'},
#     'referralId': 'v-1592314867',
#     'hasPerk': False},
#    {'id': '4ad74066f964a5201c0921e3',
#     'name': 'Waitrose & Partners',
#     'location': {'address': '21 Liverpool Road',
#      'lat': 51.53389316487267,
#      'lng': -0.10725447879826788,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.53389316487267,
#        'lng': -0.10725447879826788}],
#      'distance': 10542,
#      'postalCode': 'N1 9EN',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['21 Liverpool Road',
#       'London',
#       'Greater London',
#       'N1 9EN',
#       'United Kingdom']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '560500047'},
#     'referralId': 'v-1592314867',
#     'hasPerk': False},
#    {'id': '4bae11d2f964a520bb803be3',
#     'name': 'Morrisons',
#     'location': {'address': '19 Aldermans Hill',
#      'lat': 51.61759020766987,
#      'lng': -0.11052846908569336,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.61759020766987,
#        'lng': -0.11052846908569336}],
#      'distance': 8777,
#      'postalCode': 'N13 4EU',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['19 Aldermans Hill',
#       'London',
#       'Greater London',
#       'N13 4EU',
#       'United Kingdom']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314867',
#     'hasPerk': False},
#    {'id': '4bd87d6df645c9b6f110a8e0',
#     'name': "Sainsbury's",
#     'location': {'address': '99 Wilton Rd',
#      'lat': 51.49290802727334,
#      'lng': -0.14101248878577,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.49290802727334,
#        'lng': -0.14101248878577}],
#      'distance': 12457,
#      'postalCode': 'SW1V 1DT',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['99 Wilton Rd',
#       'London',
#       'Greater London',
#       'SW1V 1DT',
#       'United Kingdom']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314867',
#     'hasPerk': False},
#    {'id': '4aeaae79f964a5200ebc21e3',
#     'name': 'Lidl',
#     'location': {'address': '27 Well Street',
#      'lat': 51.5401451474208,
#      'lng': -0.0536319983599238,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.5401451474208,
#        'lng': -0.0536319983599238}],
#      'distance': 13397,
#      'postalCode': 'E9 7QX',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['27 Well Street',
#       'London',
#       'Greater London',
#       'E9 7QX',
#       'United Kingdom']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '543400539'},
#     'referralId': 'v-1592314867',
#     'hasPerk': False},
#    {'id': '4ad79cddf964a520c60c21e3',
#     'name': "Sainsbury's",
#     'location': {'address': '31-41 Liverpool Rd.',
#      'lat': 51.53419096412073,
#      'lng': -0.10769955222165173,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.53419096412073,
#        'lng': -0.10769955222165173}],
#      'distance': 10498,
#      'postalCode': 'N1 0RW',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['31-41 Liverpool Rd.',
#       'London',
#       'Greater London',
#       'N1 0RW',
#       'United Kingdom']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314867',
#     'hasPerk': False},
#    {'id': '4b97ec98f964a520c11f35e3',
#     'name': 'Waitrose & Partners',
#     'location': {'address': '40-44 St Johns Road',
#      'lat': 51.46263313312424,
#      'lng': -0.16778697177562663,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.46263313312424,
#        'lng': -0.16778697177562663}],
#      'distance': 14842,
#      'postalCode': 'SW11 1PW',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['40-44 St Johns Road',
#       'London',
#       'Greater London',
#       'SW11 1PW',
#       'United Kingdom']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314867',
#     'hasPerk': False},
#    {'id': '4b2fa28af964a5203ced24e3',
#     'name': "Sainsbury's",
#     'location': {'address': 'Williamson Road',
#      'lat': 51.577264374156734,
#      'lng': -0.09554951202700446,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.577264374156734,
#        'lng': -0.09554951202700446}],
#      'distance': 9387,
#      'postalCode': 'N4 1UJ',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Williamson Road',
#       'London',
#       'Greater London',
#       'N4 1UJ',
#       'United Kingdom']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314867',
#     'hasPerk': False},
#    {'id': '4ac518f2f964a52040ae20e3',
#     'name': 'Tesco',
#     'location': {'address': 'West Cromwell Rd, Kensington',
#      'crossStreet': 'Warwick Rd',
#      'lat': 51.49287869698524,
#      'lng': -0.20122112274335358,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.49287869698524,
#        'lng': -0.20122112274335358}],
#      'distance': 11021,
#      'postalCode': 'W14 8PB',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['West Cromwell Rd, Kensington (Warwick Rd)',
#       'London',
#       'Greater London',
#       'W14 8PB',
#       'United Kingdom']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314867',
#     'hasPerk': False},
#    {'id': '4ac518eff964a52087ad20e3',
#     'name': 'Waitrose & Partners',
#     'location': {'address': '199 Finchley Road',
#      'lat': 51.546203040110406,
#      'lng': -0.17958835182344046,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.546203040110406,
#        'lng': -0.17958835182344046}],
#      'distance': 6006,
#      'postalCode': 'NW3 6NN',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['199 Finchley Road',
#       'London',
#       'Greater London',
#       'NW3 6NN',
#       'United Kingdom']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314867',
#     'hasPerk': False},
#    {'id': '4ae346b5f964a520bf9221e3',
#     'name': 'Waitrose & Partners',
#     'location': {'address': 'Westfield London Shopping Centre',
#      'lat': 51.506385,
#      'lng': -0.219069,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.506385,
#        'lng': -0.219069}],
#      'distance': 9369,
#      'postalCode': 'W12 7GA',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Westfield London Shopping Centre',
#       'London',
#       'Greater London',
#       'W12 7GA',
#       'United Kingdom']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314867',
#     'hasPerk': False},
#    {'id': '4b0c377cf964a520103923e3',
#     'name': 'Waitrose & Partners',
#     'location': {'address': '23-39 The Brunswick Centre',
#      'lat': 51.525,
#      'lng': -0.124116,
#      'labeledLatLngs': [{'label': 'display', 'lat': 51.525, 'lng': -0.124116}],
#      'distance': 10303,
#      'postalCode': 'WC1N 1AF',
#      'cc': 'GB',
#      'neighborhood': 'Bloomsbury, London, Greater London',
#      'city': 'Bloomsbury',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['23-39 The Brunswick Centre',
#       'Bloomsbury',
#       'Greater London',
#       'WC1N 1AF',
#       'United Kingdom']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314867',
#     'hasPerk': False},
#    {'id': '4b60a52ef964a5200ef229e3',
#     'name': "Sainsbury's",
#     'location': {'address': '17-21 Camden Rd',
#      'crossStreet': 'at Camden St',
#      'lat': 51.540462488265135,
#      'lng': -0.1408706179400987,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.540462488265135,
#        'lng': -0.1408706179400987}],
#      'distance': 8276,
#      'postalCode': 'NW1 9LJ',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['17-21 Camden Rd (at Camden St)',
#       'London',
#       'Greater London',
#       'NW1 9LJ',
#       'United Kingdom']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314867',
#     'hasPerk': False}],
#   'confident': False}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                          id                 name  \
# 0  5b1ebc890d0877001c28dcd0          Sainsbury's
# 1  4b9395f9f964a520404934e3          Sainsbury's
# 2  4b40b944f964a52059ba25e3  Waitrose & Partners
# 3  4b423c50f964a520b7cf25e3          Sainsbury's
# 4  4b504755f964a520a61f27e3  Waitrose & Partners
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '52f2ab2ebcbc57f1066b8b46', 'name': 'S...  v-1592314867    False
# 1  [{'id': '52f2ab2ebcbc57f1066b8b46', 'name': 'S...  v-1592314867    False
# 2  [{'id': '52f2ab2ebcbc57f1066b8b46', 'name': 'S...  v-1592314867    False
# 3  [{'id': '52f2ab2ebcbc57f1066b8b46', 'name': 'S...  v-1592314867    False
# 4  [{'id': '52f2ab2ebcbc57f1066b8b46', 'name': 'S...  v-1592314867    False
#
#                          location.address  location.lat  location.lng  \
# 0  Smithfield Square, High Street Hornsey     51.587939     -0.116935
# 1                27 Townmead Road, Fulham     51.467447     -0.187096
# 2                       366 Holloway Road     51.556128     -0.116124
# 3                  147-151 Balham High Rd     51.443758     -0.150874
# 4                       273 Ballards Lane     51.611384     -0.180097
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 51.58793854665387...               7798
# 1  [{'label': 'display', 'lat': 51.46744689642563...              13989
# 2  [{'label': 'display', 'lat': 51.5561281, 'lng'...               8725
# 3  [{'label': 'display', 'lat': 51.44375769596284...              17200
# 4  [{'label': 'display', 'lat': 51.6113840885588,...               4152
#
#   location.postalCode location.cc location.city  location.state  \
# 0              N8 7SA          GB        London  Greater London
# 1             SW6 2SY          GB        London  Greater London
# 2              N7 6PA          GB        London  Greater London
# 3            SW12 9AU          GB        London  Greater London
# 4             N12 8NR          GB        London  Greater London
#
#   location.country                          location.formattedAddress  \
# 0   United Kingdom  [Smithfield Square, High Street Hornsey, Londo...
# 1   United Kingdom  [27 Townmead Road, Fulham, London, Greater Lon...
# 2   United Kingdom  [366 Holloway Road, London, Greater London, N7...
# 3   United Kingdom  [147-151 Balham High Rd, London, Greater Londo...
# 4   United Kingdom  [273 Ballards Lane, London, Greater London, N1...
#
#                location.neighborhood location.crossStreet venuePage.id
# 0                                NaN                  NaN          NaN
# 1  Sands End, London, Greater London                  NaN          NaN
# 2                                NaN                  NaN          NaN
# 3                                NaN                  NaN          NaN
# 4                                NaN                  NaN          NaN

# %%
dataframe.shape
# Out:
# (30, 19)

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered.head()
# Out:
#                   name   categories                                 address  \
# 0          Sainsbury's  Supermarket  Smithfield Square, High Street Hornsey
# 1          Sainsbury's  Supermarket                27 Townmead Road, Fulham
# 2  Waitrose & Partners  Supermarket                       366 Holloway Road
# 3          Sainsbury's  Supermarket                  147-151 Balham High Rd
# 4  Waitrose & Partners  Supermarket                       273 Ballards Lane
#
#          lat       lng                                     labeledLatLngs  \
# 0  51.587939 -0.116935  [{'label': 'display', 'lat': 51.58793854665387...
# 1  51.467447 -0.187096  [{'label': 'display', 'lat': 51.46744689642563...
# 2  51.556128 -0.116124  [{'label': 'display', 'lat': 51.5561281, 'lng'...
# 3  51.443758 -0.150874  [{'label': 'display', 'lat': 51.44375769596284...
# 4  51.611384 -0.180097  [{'label': 'display', 'lat': 51.6113840885588,...
#
#    distance postalCode  cc    city           state         country  \
# 0      7798     N8 7SA  GB  London  Greater London  United Kingdom
# 1     13989    SW6 2SY  GB  London  Greater London  United Kingdom
# 2      8725     N7 6PA  GB  London  Greater London  United Kingdom
# 3     17200   SW12 9AU  GB  London  Greater London  United Kingdom
# 4      4152    N12 8NR  GB  London  Greater London  United Kingdom
#
#                                     formattedAddress  \
# 0  [Smithfield Square, High Street Hornsey, Londo...
# 1  [27 Townmead Road, Fulham, London, Greater Lon...
# 2  [366 Holloway Road, London, Greater London, N7...
# 3  [147-151 Balham High Rd, London, Greater Londo...
# 4  [273 Ballards Lane, London, Greater London, N1...
#
#                         neighborhood crossStreet                        id
# 0                                NaN         NaN  5b1ebc890d0877001c28dcd0
# 1  Sands End, London, Greater London         NaN  4b9395f9f964a520404934e3
# 2                                NaN         NaN  4b40b944f964a52059ba25e3
# 3                                NaN         NaN  4b423c50f964a520b7cf25e3
# 4                                NaN         NaN  4b504755f964a520a61f27e3

# %%
# add the supermarkets as green circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=3,
        color='green',
        popup=label,
        fill = True,
        fill_color='green',
        fill_opacity=0.6
    ).add_to(map_london)
    
map_london
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Simplify postcode

# %%
dataframe_filtered['postalCode'] = dataframe_filtered['postalCode'].str.split(" ", n = 1, expand = True)[0]
dataframe_filtered.head()
# Out:
#                   name   categories                                 address  \
# 0          Sainsbury's  Supermarket  Smithfield Square, High Street Hornsey
# 1          Sainsbury's  Supermarket                27 Townmead Road, Fulham
# 2  Waitrose & Partners  Supermarket                       366 Holloway Road
# 3          Sainsbury's  Supermarket                  147-151 Balham High Rd
# 4  Waitrose & Partners  Supermarket                       273 Ballards Lane
#
#          lat       lng                                     labeledLatLngs  \
# 0  51.587939 -0.116935  [{'label': 'display', 'lat': 51.58793854665387...
# 1  51.467447 -0.187096  [{'label': 'display', 'lat': 51.46744689642563...
# 2  51.556128 -0.116124  [{'label': 'display', 'lat': 51.5561281, 'lng'...
# 3  51.443758 -0.150874  [{'label': 'display', 'lat': 51.44375769596284...
# 4  51.611384 -0.180097  [{'label': 'display', 'lat': 51.6113840885588,...
#
#    distance postalCode  cc    city           state         country  \
# 0      7798         N8  GB  London  Greater London  United Kingdom
# 1     13989        SW6  GB  London  Greater London  United Kingdom
# 2      8725         N7  GB  London  Greater London  United Kingdom
# 3     17200       SW12  GB  London  Greater London  United Kingdom
# 4      4152        N12  GB  London  Greater London  United Kingdom
#
#                                     formattedAddress  \
# 0  [Smithfield Square, High Street Hornsey, Londo...
# 1  [27 Townmead Road, Fulham, London, Greater Lon...
# 2  [366 Holloway Road, London, Greater London, N7...
# 3  [147-151 Balham High Rd, London, Greater Londo...
# 4  [273 Ballards Lane, London, Greater London, N1...
#
#                         neighborhood crossStreet                        id
# 0                                NaN         NaN  5b1ebc890d0877001c28dcd0
# 1  Sands End, London, Greater London         NaN  4b9395f9f964a520404934e3
# 2                                NaN         NaN  4b40b944f964a52059ba25e3
# 3                                NaN         NaN  4b423c50f964a520b7cf25e3
# 4                                NaN         NaN  4b504755f964a520a61f27e3

# %%
dataframe_filtered.name.unique()
# Out:
# array(["Sainsbury's", 'Waitrose & Partners', 'Morrisons', 'Tesco', 'Asda',
#        'Tesco Extra', 'Lidl'], dtype=object)

# %%
df_shops = dataframe_filtered.groupby('postalCode').count()['name']

# %% [markdown]
# Search for cafes

# %%
search_query = '4bf58dd8d48988d16d941735' # Cafes
radius = 15000
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&categoryId={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=FUBQR1NVAJTE4PBVEDP1WP2GYBBCGP5YYPF2F13N1WK5FETG&client_secret=C2O004RGNK1CWTC1CYHS3PZUJDSDACW5C3NPFE0YJPGQLVFJ&ll=51.590297050000004,-0.2296322094540291&v=20180604&categoryId=4bf58dd8d48988d16d941735&radius=15000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ee8cc1b227f2f7f023f6624'},
#  'response': {'venues': [{'id': '5d510d4a3c10d100083a1779',
#     'name': "GAIL's Bakery",
#     'location': {'address': '237 Elgin Av',
#      'crossStreet': 'Randolph Av',
#      'lat': 51.529964,
#      'lng': -0.185982,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.529964,
#        'lng': -0.185982}],
#      'distance': 7364,
#      'postalCode': 'W9 1NJ',
#      'cc': 'GB',
#      'city': 'Maida Vale',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['237 Elgin Av (Randolph Av)',
#       'Maida Vale',
#       'Greater London',
#       'W9 1NJ',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314874',
#     'hasPerk': False},
#    {'id': '5a4fb411419a9e28327e19c1',
#     'name': "Sable D'or",
#     'location': {'address': "30 England's Lane",
#      'lat': 51.54599,
#      'lng': -0.16204767,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.54599,
#        'lng': -0.16204767}],
#      'distance': 6796,
#      'postalCode': 'NW3 4UE',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ["30 England's Lane",
#       'London',
#       'Greater London',
#       'NW3 4UE',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314874',
#     'hasPerk': False},
#    {'id': '5873c0fd0bc55b0a6740ec93',
#     'name': 'Boys N Berry',
#     'location': {'address': '839 Fulham Rd',
#      'lat': 51.47492069214313,
#      'lng': -0.20631400134594996,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.47492069214313,
#        'lng': -0.20631400134594996}],
#      'distance': 12944,
#      'postalCode': 'SW6 5FQ',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['839 Fulham Rd',
#       'London',
#       'Greater London',
#       'SW6 5FQ',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314874',
#     'hasPerk': False},
#    {'id': '5cd151736bdee6002c9dd8a5',
#     'name': 'Megan’s',
#     'location': {'address': '27 Circus West Village',
#      'lat': 51.483417,
#      'lng': -0.146219,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.483417,
#        'lng': -0.146219}],
#      'distance': 13225,
#      'postalCode': 'SW11 8NN',
#      'cc': 'GB',
#      'city': 'Battersea',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['27 Circus West Village',
#       'Battersea',
#       'Greater London',
#       'SW11 8NN',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314874',
#     'hasPerk': False},
#    {'id': '5a9bbf38bfc6d04517520791',
#     'name': 'Grain Artisan Sourdough',
#     'location': {'address': "36 England's Lane",
#      'lat': 51.54591,
#      'lng': -0.162218,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.54591,
#        'lng': -0.162218}],
#      'distance': 6795,
#      'postalCode': 'NW3 4UE',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ["36 England's Lane",
#       'London',
#       'Greater London',
#       'NW3 4UE',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314874',
#     'hasPerk': False},
#    {'id': '5d500223bdb79a000819f532',
#     'name': 'Hidden Coffee',
#     'location': {'address': '47-49 Camden Rd',
#      'crossStreet': 'Royal College Street',
#      'lat': 51.541777,
#      'lng': -0.138658,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.541777,
#        'lng': -0.138658}],
#      'distance': 8294,
#      'postalCode': 'NW1 9LS',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['47-49 Camden Rd (Royal College Street)',
#       'London',
#       'Greater London',
#       'NW1 9LS',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314874',
#     'hasPerk': False},
#    {'id': '5ce129e0dd8442002c3cfc60',
#     'name': 'Brunswick East Bakehouse',
#     'location': {'lat': 51.55443,
#      'lng': -0.066427,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.55443,
#        'lng': -0.066427}],
#      'distance': 11976,
#      'postalCode': 'E8 2BT',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['London',
#       'Greater London',
#       'E8 2BT',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'shortName': 'Breakfast',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314874',
#     'hasPerk': False},
#    {'id': '5eda12b88cd820000853968a',
#     'name': 'Notting Hill Coffee Project',
#     'location': {'address': 'Notting Hill Gate',
#      'lat': 51.509037,
#      'lng': -0.196711,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.509037,
#        'lng': -0.196711}],
#      'distance': 9328,
#      'postalCode': 'W11',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Notting Hill Gate',
#       'London',
#       'Greater London',
#       'W11',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314874',
#     'hasPerk': False},
#    {'id': '5eda01a5574a2b0008fcfccf',
#     'name': 'Saj Cafe',
#     'location': {'lat': 51.506042,
#      'lng': -0.2310485,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.506042,
#        'lng': -0.2310485}],
#      'distance': 9379,
#      'postalCode': 'W12 8NR',
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['W12 8NR', 'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314874',
#     'hasPerk': False},
#    {'id': '59989fbabfc6d00305ddab7e',
#     'name': 'EL&N',
#     'location': {'address': '48 Park Ln',
#      'crossStreet': 'Deanery St',
#      'lat': 51.506815937331424,
#      'lng': -0.15188813209533691,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.506815937331424,
#        'lng': -0.15188813209533691}],
#      'distance': 10738,
#      'postalCode': 'W1K 1PR',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['48 Park Ln (Deanery St)',
#       'London',
#       'Greater London',
#       'W1K 1PR',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314874',
#     'hasPerk': False},
#    {'id': '5641abb038fa7b01648ae33e',
#     'name': 'Carpo',
#     'location': {'address': '5 Montpelier St',
#      'lat': 51.49894917422254,
#      'lng': -0.1654982068808371,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.49894917422254,
#        'lng': -0.1654982068808371}],
#      'distance': 11095,
#      'postalCode': 'SW7 1EX',
#      'cc': 'GB',
#      'neighborhood': 'Knightsbridge',
#      'city': 'Knightsbridge',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['5 Montpelier St',
#       'Knightsbridge',
#       'Greater London',
#       'SW7 1EX',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314874',
#     'hasPerk': False},
#    {'id': '5c164f9facc5f5002c24c014',
#     'name': 'EL&N',
#     'location': {'address': '42 Hans Cr',
#      'lat': 51.499646692197885,
#      'lng': -0.16224145889282227,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.499646692197885,
#        'lng': -0.16224145889282227}],
#      'distance': 11117,
#      'postalCode': 'SW1X 0LZ',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['42 Hans Cr',
#       'London',
#       'Greater London',
#       'SW1X 0LZ',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314874',
#     'hasPerk': False},
#    {'id': '4b5303c1f964a5209f8c27e3',
#     'name': 'Pimlico Fresh',
#     'location': {'address': '86 Wilton Rd',
#      'crossStreet': 'Warwick Way',
#      'lat': 51.492455838394534,
#      'lng': -0.14018580975487518,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.492455838394534,
#        'lng': -0.14018580975487518}],
#      'distance': 12529,
#      'postalCode': 'SW1V 1DN',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['86 Wilton Rd (Warwick Way)',
#       'London',
#       'Greater London',
#       'SW1V 1DN',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314874',
#     'hasPerk': False},
#    {'id': '4b892b07f964a520922032e3',
#     'name': 'Lido Café',
#     'location': {'address': 'Rotten Row',
#      'lat': 51.504662277041746,
#      'lng': -0.1696228981018066,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.504662277041746,
#        'lng': -0.1696228981018066}],
#      'distance': 10398,
#      'postalCode': 'W2 2UH',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Rotten Row',
#       'London',
#       'Greater London',
#       'W2 2UH',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314874',
#     'hasPerk': False},
#    {'id': '4bf7a99e5317a593396cfe7e',
#     'name': "GAIL's Bakery",
#     'location': {'address': '282 Chiswick High Rd',
#      'lat': 51.4925472785291,
#      'lng': -0.2598046651439941,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.4925472785291,
#        'lng': -0.2598046651439941}],
#      'distance': 11080,
#      'postalCode': 'W4 1PA',
#      'cc': 'GB',
#      'city': 'Chiswick',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['282 Chiswick High Rd',
#       'Chiswick',
#       'Greater London',
#       'W4 1PA',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314874',
#     'hasPerk': False},
#    {'id': '4baf60fff964a52080fb3be3',
#     'name': 'Montparnasse Cafe',
#     'location': {'address': '22 Thackeray St',
#      'lat': 51.500528,
#      'lng': -0.189055,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.500528,
#        'lng': -0.189055}],
#      'distance': 10380,
#      'postalCode': 'W8 5ET',
#      'cc': 'GB',
#      'city': 'Kensington',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['22 Thackeray St',
#       'Kensington',
#       'Greater London',
#       'W8 5ET',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d10c941735',
#       'name': 'French Restaurant',
#       'pluralName': 'French Restaurants',
#       'shortName': 'French',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314874',
#     'hasPerk': False},
#    {'id': '50f68e92e4b0507e7689e659',
#     'name': "L'ETO Caffè",
#     'location': {'address': '10 West Halkin St',
#      'lat': 51.49865091970132,
#      'lng': -0.1569692644544991,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.49865091970132,
#        'lng': -0.1569692644544991}],
#      'distance': 11374,
#      'postalCode': 'SW1X 8JL',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['10 West Halkin St',
#       'London',
#       'Greater London',
#       'SW1X 8JL',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314874',
#     'hasPerk': False},
#    {'id': '58a576b8f8572431aec041b8',
#     'name': 'Kobo Cafe',
#     'location': {'lat': 51.534988,
#      'lng': -0.104149,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.534988,
#        'lng': -0.104149}],
#      'distance': 10644,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314874',
#     'hasPerk': False},
#    {'id': '5ba39df6531593002c5198ca',
#     'name': 'Jolene',
#     'location': {'address': '21 Newington Green',
#      'lat': 51.55140024630812,
#      'lng': -0.08480229009676096,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.55140024630812,
#        'lng': -0.08480229009676096}],
#      'distance': 10916,
#      'postalCode': 'N16 9PU',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['21 Newington Green',
#       'London',
#       'Greater London',
#       'N16 9PU',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314874',
#     'hasPerk': False},
#    {'id': '4e8ef5baa17c23f1bd81b6c1',
#     'name': 'Pret A Manger',
#     'location': {'address': '87-88 Strand',
#      'crossStreet': 'at Carting Ln',
#      'lat': 51.51042153712988,
#      'lng': -0.12151801041434712,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51042153712988,
#        'lng': -0.12151801041434712}],
#      'distance': 11621,
#      'postalCode': 'WC2R 0DW',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['87-88 Strand (at Carting Ln)',
#       'London',
#       'Greater London',
#       'WC2R 0DW',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314874',
#     'hasPerk': False},
#    {'id': '511e0b21c84ca6ec8e267b7a',
#     'name': 'The Monocle Café',
#     'location': {'address': '18 Chiltern St',
#      'lat': 51.518781088522644,
#      'lng': -0.15461579198017716,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.518781088522644,
#        'lng': -0.15461579198017716}],
#      'distance': 9504,
#      'postalCode': 'W1U 7QA',
#      'cc': 'GB',
#      'city': 'Marylebone',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['18 Chiltern St',
#       'Marylebone',
#       'Greater London',
#       'W1U 7QA',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '72450462'},
#     'referralId': 'v-1592314874',
#     'hasPerk': False},
#    {'id': '540c1d79498e77fa82558f63',
#     'name': 'Canada Water Café',
#     'location': {'address': '40 Surrey Quays Rd',
#      'lat': 51.49864481917547,
#      'lng': -0.0489721315991805,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.49864481917547,
#        'lng': -0.0489721315991805}],
#      'distance': 16140,
#      'postalCode': 'SE16 7DX',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['40 Surrey Quays Rd',
#       'London',
#       'Greater London',
#       'SE16 7DX',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314874',
#     'hasPerk': False},
#    {'id': '57c16071498e5d14ae19bb3c',
#     'name': "GAIL's Bakery",
#     'location': {'address': '87 Lauriston Rd',
#      'lat': 51.537828792327545,
#      'lng': -0.04476815122626007,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.537828792327545,
#        'lng': -0.04476815122626007}],
#      'distance': 14062,
#      'postalCode': 'E9 7HJ',
#      'cc': 'GB',
#      'city': 'Victoria Park',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['87 Lauriston Rd',
#       'Victoria Park',
#       'Greater London',
#       'E9 7HJ',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314874',
#     'hasPerk': False},
#    {'id': '53a6c643498ef54d0297a4c0',
#     'name': 'Yellow Warbler',
#     'location': {'address': '9 Northwold Rd',
#      'lat': 51.563178262743556,
#      'lng': -0.07244953741581871,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.563178262743556,
#        'lng': -0.07244953741581871}],
#      'distance': 11285,
#      'postalCode': 'N16 7HL',
#      'cc': 'GB',
#      'neighborhood': 'Hackney',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['9 Northwold Rd',
#       'London',
#       'Greater London',
#       'N16 7HL',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '88739206'},
#     'referralId': 'v-1592314874',
#     'hasPerk': False},
#    {'id': '4b9df945f964a520e2c436e3',
#     'name': 'Garden Breakfast Cafe',
#     'location': {'address': '3 Goldhurst Terrace',
#      'lat': 51.54602419009194,
#      'lng': -0.1793049122780168,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.54602419009194,
#        'lng': -0.1793049122780168}],
#      'distance': 6034,
#      'postalCode': 'NW6 3HX',
#      'cc': 'GB',
#      'city': 'Camden Town',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['3 Goldhurst Terrace',
#       'Camden Town',
#       'Greater London',
#       'NW6 3HX',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314874',
#     'hasPerk': False},
#    {'id': '561fc5ae498e940a1bb3dd72',
#     'name': 'Music & Beans',
#     'location': {'address': '461 Green Lanes',
#      'lat': 51.579910854631095,
#      'lng': -0.09926242143637126,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.579910854631095,
#        'lng': -0.09926242143637126}],
#      'distance': 9091,
#      'postalCode': 'N4 1HE',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['461 Green Lanes',
#       'London',
#       'Greater London',
#       'N4 1HE',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314874',
#     'hasPerk': False},
#    {'id': '4ae30e9ff964a520289021e3',
#     'name': 'Planet Organic',
#     'location': {'address': '64 Essex Rd.',
#      'lat': 51.537966952053225,
#      'lng': -0.09967632951781946,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.537966952053225,
#        'lng': -0.09967632951781946}],
#      'distance': 10714,
#      'postalCode': 'N1 8LR',
#      'cc': 'GB',
#      'city': 'Islington',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['64 Essex Rd.',
#       'Islington',
#       'Greater London',
#       'N1 8LR',
#       'United Kingdom']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b45',
#       'name': 'Organic Grocery',
#       'pluralName': 'Organic Groceries',
#       'shortName': 'Organic Grocery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314874',
#     'hasPerk': False},
#    {'id': '4f0997bde4b0882d2441d2d6',
#     'name': 'Clissold House',
#     'location': {'address': 'Clissold Park',
#      'lat': 51.56126082697065,
#      'lng': -0.08612977829842676,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.56126082697065,
#        'lng': -0.08612977829842676}],
#      'distance': 10440,
#      'postalCode': 'N16',
#      'cc': 'GB',
#      'city': 'Stoke Newington',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Clissold Park',
#       'Stoke Newington',
#       'Greater London',
#       ' N16',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314874',
#     'hasPerk': False},
#    {'id': '509e89d5e4b09f01852da56b',
#     'name': 'The Place to Eat',
#     'location': {'address': '101 The Arcade',
#      'crossStreet': 'Westfield Stratford City',
#      'lat': 51.543535308267664,
#      'lng': -0.00898232777625442,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.543535308267664,
#        'lng': -0.00898232777625442}],
#      'distance': 16131,
#      'postalCode': 'E20',
#      'cc': 'GB',
#      'city': 'Stratford',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['101 The Arcade (Westfield Stratford City)',
#       'Stratford',
#       'Greater London',
#       ' E20',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1592314874',
#     'hasPerk': False}],
#   'confident': False}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                          id                     name  \
# 0  5d510d4a3c10d100083a1779            GAIL's Bakery
# 1  5a4fb411419a9e28327e19c1               Sable D'or
# 2  5873c0fd0bc55b0a6740ec93             Boys N Berry
# 3  5cd151736bdee6002c9dd8a5                  Megan’s
# 4  5a9bbf38bfc6d04517520791  Grain Artisan Sourdough
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...  v-1592314874    False
# 1  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1592314874    False
# 2  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1592314874    False
# 3  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1592314874    False
# 4  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1592314874    False
#
#          location.address location.crossStreet  location.lat  location.lng  \
# 0            237 Elgin Av          Randolph Av     51.529964     -0.185982
# 1       30 England's Lane                  NaN     51.545990     -0.162048
# 2           839 Fulham Rd                  NaN     51.474921     -0.206314
# 3  27 Circus West Village                  NaN     51.483417     -0.146219
# 4       36 England's Lane                  NaN     51.545910     -0.162218
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 51.529964, 'lng':...               7364
# 1  [{'label': 'display', 'lat': 51.54599, 'lng': ...               6796
# 2  [{'label': 'display', 'lat': 51.47492069214313...              12944
# 3  [{'label': 'display', 'lat': 51.483417, 'lng':...              13225
# 4  [{'label': 'display', 'lat': 51.54591, 'lng': ...               6795
#
#   location.postalCode location.cc location.city  location.state  \
# 0              W9 1NJ          GB    Maida Vale  Greater London
# 1             NW3 4UE          GB        London  Greater London
# 2             SW6 5FQ          GB        London  Greater London
# 3            SW11 8NN          GB     Battersea  Greater London
# 4             NW3 4UE          GB        London  Greater London
#
#   location.country                          location.formattedAddress  \
# 0   United Kingdom  [237 Elgin Av (Randolph Av), Maida Vale, Great...
# 1   United Kingdom  [30 England's Lane, London, Greater London, NW...
# 2   United Kingdom  [839 Fulham Rd, London, Greater London, SW6 5F...
# 3   United Kingdom  [27 Circus West Village, Battersea, Greater Lo...
# 4   United Kingdom  [36 England's Lane, London, Greater London, NW...
#
#   location.neighborhood venuePage.id
# 0                   NaN          NaN
# 1                   NaN          NaN
# 2                   NaN          NaN
# 3                   NaN          NaN
# 4                   NaN          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered.head()
# Out:
#                       name categories                 address  crossStreet  \
# 0            GAIL's Bakery     Bakery            237 Elgin Av  Randolph Av
# 1               Sable D'or       Café       30 England's Lane          NaN
# 2             Boys N Berry       Café           839 Fulham Rd          NaN
# 3                  Megan’s       Café  27 Circus West Village          NaN
# 4  Grain Artisan Sourdough       Café       36 England's Lane          NaN
#
#          lat       lng                                     labeledLatLngs  \
# 0  51.529964 -0.185982  [{'label': 'display', 'lat': 51.529964, 'lng':...
# 1  51.545990 -0.162048  [{'label': 'display', 'lat': 51.54599, 'lng': ...
# 2  51.474921 -0.206314  [{'label': 'display', 'lat': 51.47492069214313...
# 3  51.483417 -0.146219  [{'label': 'display', 'lat': 51.483417, 'lng':...
# 4  51.545910 -0.162218  [{'label': 'display', 'lat': 51.54591, 'lng': ...
#
#    distance postalCode  cc        city           state         country  \
# 0      7364     W9 1NJ  GB  Maida Vale  Greater London  United Kingdom
# 1      6796    NW3 4UE  GB      London  Greater London  United Kingdom
# 2     12944    SW6 5FQ  GB      London  Greater London  United Kingdom
# 3     13225   SW11 8NN  GB   Battersea  Greater London  United Kingdom
# 4      6795    NW3 4UE  GB      London  Greater London  United Kingdom
#
#                                     formattedAddress neighborhood  \
# 0  [237 Elgin Av (Randolph Av), Maida Vale, Great...          NaN
# 1  [30 England's Lane, London, Greater London, NW...          NaN
# 2  [839 Fulham Rd, London, Greater London, SW6 5F...          NaN
# 3  [27 Circus West Village, Battersea, Greater Lo...          NaN
# 4  [36 England's Lane, London, Greater London, NW...          NaN
#
#                          id
# 0  5d510d4a3c10d100083a1779
# 1  5a4fb411419a9e28327e19c1
# 2  5873c0fd0bc55b0a6740ec93
# 3  5cd151736bdee6002c9dd8a5
# 4  5a9bbf38bfc6d04517520791

# %%
dataframe_filtered['postalCode'] = dataframe_filtered['postalCode'].str.split(" ", n = 1, expand = True)[0]
df_cafes = dataframe_filtered.groupby('postalCode').count()['name']
df_cafes
# Out:
# postalCode
# E20     1
# E8      1
# E9      1
# N1      1
# N16     3
# N4      1
# NW1     1
# NW3     2
# NW6     1
# SE16    1
# SW11    1
# SW1V    1
# SW1X    2
# SW6     1
# SW7     1
# W11     1
# W12     1
# W1K     1
# W1U     1
# W2      1
# W4      1
# W8      1
# W9      1
# WC2R    1
# Name: name, dtype: int64

# %%
df_rents_2 = df_rents.merge(df_cafes, how='left', left_on='Region', right_on='postalCode').fillna(0)
df_rents_2 = df_rents_2.rename(columns={"name": "Cafes"})
df_rents_2
# Out:
#    Postcode  Latitude  Longitude  \
# 0        E1   51.5163  -0.060428
# 1       E1W   51.5118  -0.059323
# 2        E2   51.5301  -0.062251
# 3        E3   51.5282  -0.025800
# 4        E4   51.6238  -0.003245
# ..      ...       ...        ...
# 81      W10   51.5202  -0.221196
# 82      W11   51.5128  -0.216585
# 83      W12   51.5094  -0.238236
# 84      W13   51.5131  -0.321423
# 85      W14   51.4954  -0.211163
#
#                                             Town/Area                  Region  \
# 0   Aldgate, Bishopsgate, Whitechapel, Shoreditch,...           Tower Hamlets
# 1                                             Wapping           Tower Hamlets
# 2   Bethnal Green, Haggerston, Shoreditch, Cambrid...           Tower Hamlets
# 3   Bow, Bromley-by-Bow, Old Ford, Mile End, Three...           Tower Hamlets
# 4                Chingford, Sewardstone, Highams Park          Waltham Forest
# ..                                                ...                     ...
# 81                      North Kensington, Queens Park  Kensington And Chelsea
# 82                         Notting Hill, Holland Park  Kensington And Chelsea
# 83                         Shepherds Bush, White City  Hammersmith And Fulham
# 84                           West Ealing, Northfields                  Ealing
# 85  West Kensington, Kensington Olympia, Holland Park  Kensington And Chelsea
#
#     Rent  Distance University  Distance Centre  Total Distance  Cafes
# 0   1494            20.541551         8.262813       28.804364    0.0
# 1   1494            20.858766         8.356972       29.215738    0.0
# 2   1494            19.785227         8.340069       28.125296    0.0
# 3   1494            23.701012        12.255042       35.956053    0.0
# 4   1089            25.455246        19.331905       44.787152    0.0
# ..   ...                  ...              ...             ...    ...
# 81  2062             7.853146         9.720280       17.573426    0.0
# 82  2062             8.741294         9.144339       17.885632    0.0
# 83  1454             9.048913        11.546536       20.595449    0.0
# 84  1216            13.340596        20.802584       34.143179    0.0
# 85  2062            10.753435         8.683957       19.437392    0.0
#
# [86 rows x 10 columns]

# %%
df_rents_3 = df_rents_2.merge(df_shops, how='left', left_on='Region', right_on='postalCode').fillna(0)
df_rents_3 = df_rents_3.rename(columns={"name": "Shops"})
df_rents_3
# Out:
#    Postcode  Latitude  Longitude  \
# 0        E1   51.5163  -0.060428
# 1       E1W   51.5118  -0.059323
# 2        E2   51.5301  -0.062251
# 3        E3   51.5282  -0.025800
# 4        E4   51.6238  -0.003245
# ..      ...       ...        ...
# 81      W10   51.5202  -0.221196
# 82      W11   51.5128  -0.216585
# 83      W12   51.5094  -0.238236
# 84      W13   51.5131  -0.321423
# 85      W14   51.4954  -0.211163
#
#                                             Town/Area                  Region  \
# 0   Aldgate, Bishopsgate, Whitechapel, Shoreditch,...           Tower Hamlets
# 1                                             Wapping           Tower Hamlets
# 2   Bethnal Green, Haggerston, Shoreditch, Cambrid...           Tower Hamlets
# 3   Bow, Bromley-by-Bow, Old Ford, Mile End, Three...           Tower Hamlets
# 4                Chingford, Sewardstone, Highams Park          Waltham Forest
# ..                                                ...                     ...
# 81                      North Kensington, Queens Park  Kensington And Chelsea
# 82                         Notting Hill, Holland Park  Kensington And Chelsea
# 83                         Shepherds Bush, White City  Hammersmith And Fulham
# 84                           West Ealing, Northfields                  Ealing
# 85  West Kensington, Kensington Olympia, Holland Park  Kensington And Chelsea
#
#     Rent  Distance University  Distance Centre  Total Distance  Cafes  Shops
# 0   1494            20.541551         8.262813       28.804364    0.0    0.0
# 1   1494            20.858766         8.356972       29.215738    0.0    0.0
# 2   1494            19.785227         8.340069       28.125296    0.0    0.0
# 3   1494            23.701012        12.255042       35.956053    0.0    0.0
# 4   1089            25.455246        19.331905       44.787152    0.0    0.0
# ..   ...                  ...              ...             ...    ...    ...
# 81  2062             7.853146         9.720280       17.573426    0.0    0.0
# 82  2062             8.741294         9.144339       17.885632    0.0    0.0
# 83  1454             9.048913        11.546536       20.595449    0.0    0.0
# 84  1216            13.340596        20.802584       34.143179    0.0    0.0
# 85  2062            10.753435         8.683957       19.437392    0.0    0.0
#
# [86 rows x 11 columns]
